# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os

import mlflow
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

from chesswinnerprediction.models.naive_model import estimate_prediction_by_elo, log_naive_prediction
from chesswinnerprediction.baseline.utils import (
    estimate_baseline_model,
    get_x_and_y,
    get_class_weights,
    transform_and_scale_df,
)
from chesswinnerprediction.baseline.constants import BASELINE_RANDOM_STATE
from chesswinnerprediction.constants import DRAW_STR, PROCESSED_FOLDER_PATH
from config import BASELINE_EXPERIMENT, MLRUNS_FOLDER_PATH

# %% [markdown]
# ## MLFlow Configuration

# %%
mlflow.set_tracking_uri(MLRUNS_FOLDER_PATH)

# %%
if mlflow.get_experiment_by_name(BASELINE_EXPERIMENT) is not None:
    experiment_id = mlflow.get_experiment_by_name(BASELINE_EXPERIMENT).experiment_id
else:
    experiment_id = mlflow.create_experiment(BASELINE_EXPERIMENT)

# %%
mlflow.set_experiment(experiment_id=experiment_id)
mlflow.sklearn.autolog()

# %% [markdown]
# ## Data Preparation

# %%
data_dir = "lichess_db_standard_rated_2017-05"
data_path = os.path.join(PROCESSED_FOLDER_PATH, data_dir)
mlflow.sklearn.autolog(disable=False)

# %%
train_df = pd.read_csv(os.path.join(data_path, "train.csv"))
valid_df = pd.read_csv(os.path.join(data_path, "valid.csv"))

# %%
train_df.head()
# Out:
#                           Event  WhiteElo  BlackElo TimeControl Result  \
# 0       Rated Bullet tournament      1425      1516        30+0    1-0
# 1              Rated Blitz game      1573      1612       180+0    0-1
# 2       Rated Bullet tournament      1643      1679        60+0    0-1
# 3              Rated Blitz game      1596      1572       180+2    1-0
# 4  Rated UltraBullet tournament      1354      1367        15+0    0-1
#
#     Termination  ECO        White           Black  EloDiff  MeanElo  BaseTime  \
# 0  Time forfeit  A46  luptatoarea        PawnSean      -91   1470.5        30
# 1        Normal  C40      Tregart          mostar      -39   1592.5       180
# 2        Normal  A20   CAMPOMANES        selobiyo      -36   1661.0        60
# 3        Normal  B13     leo_E232  theonionknight       24   1584.0       180
# 4  Time forfeit  B15      eugenia       juanfer90      -13   1360.5        15
#
#    IncrementTime  ZeroIncrementTime  ResultEncoded  WhiteWin  BlackWin  Draw  \
# 0              0                  1              1         1         0     0
# 1              0                  1              0         0         1     0
# 2              0                  1              0         0         1     0
# 3              2                  0              1         1         0     0
# 4              0                  1              0         0         1     0
#
#                                      times_in_second  GameDuration
# 0  [30, 30, 29, 30, 28, 30, 28, 30, 27, 30, 26, 3...            56
# 1  [180, 180, 179, 178, 175, 174, 175, 173, 166, ...           210
# 2  [60, 60, 59, 59, 59, 59, 58, 59, 57, 58, 56, 5...            56
# 3  [180, 180, 181, 182, 181, 180, 181, 180, 179, ...           426
# 4  [15, 15, 15, 15, 15, 15, 14, 14, 13, 13, 13, 1...            26

# %%
std_scaler = StandardScaler()
train_data = transform_and_scale_df(train_df, std_scaler)
valid_data = transform_and_scale_df(valid_df, std_scaler, fit_scaler=False)

# %% [markdown]
# ## Naive Prediction
# Let's implement a naive prediction model. This model will predict that the player with the highest rating will win the game. I will attempt to predict the result both with and without considering draws.

# %%
def apply_naive_prediction(predict_draws):
    accuracy = estimate_prediction_by_elo(
        valid_df["WhiteElo"],
        valid_df["BlackElo"],
        valid_df["Result"],
        count_draws=predict_draws,
    )
    
    print(f"\nCount draws: {predict_draws}")
    print(f"\tAccuracy: {round(accuracy * 100, 2)}%")
    
    log_naive_prediction(
        valid_df[["WhiteElo", "BlackElo"]], valid_df["Result"], accuracy, predict_draws
    )

# %%
print("\t\tNaive prediction (player with the highest rating wins)")
apply_naive_prediction(predict_draws=False)
apply_naive_prediction(predict_draws=True)
# Out:
# 		Naive prediction (player with the highest rating wins)
#
# Count draws: False
# 	Accuracy: 60.06%
#
# Count draws: True
# 	Accuracy: 58.46%

# %% [markdown]
# As you can see, neglecting draws results in only a slight decrease in accuracy (-1.5%)

# %% [markdown]
# ## Class Imbalance
# Let's compute class weights for the logistic regression model

# %%
no_draws_results = train_df["Result"][train_df["Result"] != DRAW_STR]
scip_draws_class_weights = get_class_weights(no_draws_results, verbose=True)
# Out:
# Class weights:
# 	1-0: 0.9818443943627501
# 	0-1: 1.018839697887594

# %%
include_draws_class_weights = get_class_weights(train_df["Result"], verbose=True)
# Out:
# Class weights:
# 	1-0: 0.6719252445731612
# 	0-1: 0.6972429817947734
# 	1/2-1/2: 12.900070154830079

# %% [markdown]
# ## Logistic Regression Model
# Let's implement a logistic regression model to predict the outcome of the game.
#
# I will try to predict the result both with and without considering draws.

# %%
def apply_logistic_regression(
    predict_draws,
    train,
    valid,
    penalty="l1",
    solver="saga",
    max_iter=300,
    tol=1e-3,
    c=0.01,
    return_model=False,
):
    X_train, y_train = get_x_and_y(train, predict_draws=predict_draws)
    X_valid, y_valid = get_x_and_y(valid, predict_draws=predict_draws)

    model = LogisticRegression(
        C=c,  # smaller value -> stronger regularization
        random_state=BASELINE_RANDOM_STATE,
        class_weight=get_class_weights(y_train),
        tol=tol,
        max_iter=max_iter,
        penalty=penalty,
        solver=solver,
    )
    
    model.fit(X_train, y_train)

    feature_importance = model.coef_
    estimate_baseline_model(
        model, feature_importance, X_train, y_train, X_valid, y_valid
    )
    mlflow.log_param("predict_draws", predict_draws)
    
    if return_model:
        return model

# %% [markdown]
# #### Predicting Without Draws Using L2 Penalties

# %%
with mlflow.start_run(run_name="L2; no draws: LogiReg"):
    l2_no_draws_model = apply_logistic_regression(
        predict_draws=False, train=train_data, valid=valid_data, penalty="l2", tol=0.01
    )
# Out:
# Log Loss on test data: 0.6562
# Balanced Accuracy on test data: 60.14%
#
#
#                                                 Classification Report
#                          Train Report                                      Validation Report
#               precision    recall  f1-score   support         precision    recall  f1-score   support
#          0-1       0.59      0.60      0.60    378005              0.59      0.60      0.59     45215
#          1-0       0.61      0.60      0.61    392248              0.61      0.61      0.61     47511
#     accuracy                           0.60    770253                                  0.60     92726
#    macro avg       0.60      0.60      0.60    770253              0.60      0.60      0.60     92726
# weighted avg       0.60      0.60      0.60    770253              0.60      0.60      0.60     92726

# %% [markdown]
# #### Predicting Without Draws Using L2 Penalties

# %%
with mlflow.start_run(run_name="L1; no draws: LogiReg"):
    apply_logistic_regression(
        predict_draws=False, train=train_data, valid=valid_data, penalty="l1", tol=0.01
    )
# Out:
# Log Loss on test data: 0.6562
# Balanced Accuracy on test data: 60.14%
#
#
#                                                 Classification Report
#                          Train Report                                      Validation Report
#               precision    recall  f1-score   support         precision    recall  f1-score   support
#          0-1       0.59      0.60      0.60    378005              0.59      0.59      0.59     45215
#          1-0       0.61      0.61      0.61    392248              0.61      0.61      0.61     47511
#     accuracy                           0.60    770253                                  0.60     92726
#    macro avg       0.60      0.60      0.60    770253              0.60      0.60      0.60     92726
# weighted avg       0.60      0.60      0.60    770253              0.60      0.60      0.60     92726

# %% [markdown]
# Accuracy is close to naive prediction (around 60%). The most important feature is the difference in ELO, which is especially evident when using L1 penalty.

# %% [markdown]
# #### Predicting With Draws Using L2 Penalties

# %%
with mlflow.start_run(run_name="L2; predict draws: LogiReg"):
    apply_logistic_regression(
        predict_draws=True, train=train_data, valid=valid_data, penalty="l2", tol=0.01
    )
# Out:
# Log Loss on test data: 1.0381
# Balanced Accuracy on test data: 46.56%
#
#
#                                                 Classification Report
#                          Train Report                                      Validation Report
#               precision    recall  f1-score   support         precision    recall  f1-score   support
#          0-1       0.59      0.42      0.49    378005              0.59      0.42      0.49     45215
#          1-0       0.61      0.41      0.49    392248              0.61      0.41      0.49     47511
#      1/2-1/2       0.04      0.57      0.08     20431              0.05      0.57      0.09      2537
#     accuracy                           0.42    790684                                  0.42     95263
#    macro avg       0.42      0.47      0.35    790684              0.42      0.47      0.36     95263
# weighted avg       0.59      0.42      0.48    790684              0.59      0.42      0.48     95263

# %% [markdown]
# Of course, predicting draws has negatively impacted the overall picture: both recall and F1 score have dropped significantly. Draws have poor precision and F1 score, but quite decent recall.
#
# It's also interesting to note, that the feature importance chart looks completely different here.

# %%
with mlflow.start_run(run_name="L1; predict draws: LogiReg"):
    apply_logistic_regression(
        predict_draws=True, train=train_data, valid=valid_data, penalty="l1", tol=0.008
    )
# Out:
# Log Loss on test data: 1.0381
# Balanced Accuracy on test data: 46.6%
#
#
#                                                 Classification Report
#                          Train Report                                      Validation Report
#               precision    recall  f1-score   support         precision    recall  f1-score   support
#          0-1       0.59      0.42      0.49    378005              0.59      0.42      0.49     45215
#          1-0       0.61      0.41      0.49    392248              0.61      0.42      0.49     47511
#      1/2-1/2       0.04      0.57      0.08     20431              0.05      0.57      0.09      2537
#     accuracy                           0.42    790684                                  0.42     95263
#    macro avg       0.42      0.47      0.35    790684              0.42      0.47      0.36     95263
# weighted avg       0.59      0.42      0.48    790684              0.59      0.42      0.48     95263

# %% [markdown]
# The L1 penalty moved EloDiff to the top position again. Interestingly, this did not affect the model's results. Both models have identical precision, recall, and F1 scores.

# %% [markdown]
# ## Partial Feature Training

# %%
def implement_partial_feature_training(features_list, return_model=False):
    """:param features_list: with "Result" column"""
    model = apply_logistic_regression(
        predict_draws=True,
        train=train_data[features_list],
        valid=valid_data[features_list],
        penalty="l2",
        tol=0.01,
        c=1,
        return_model=return_model,
    )
    if return_model:
        return model

# %% [markdown]
# ### "WhiteElo", "BlackElo", "MeanElo"

# %%
implement_partial_feature_training(
    features_list=["WhiteElo", "BlackElo", "MeanElo", "Result"]
)
# Out:
# 2024/08/08 20:04:39 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '346c77a79d0e4ebda976bd721ae9aa5d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 implement_partial_feature_training(
#       2     features_list=["WhiteElo", "BlackElo", "MeanElo", "Result"]
#       3 )
#
# Cell In[19], line 3, in implement_partial_feature_training(features_list, return_model)
#       1 def implement_partial_feature_training(features_list, return_model=False):
#       2     """:param features_list: with "Result" column"""
# ----> 3     model = apply_logistic_regression(
#       4         predict_draws=True,
#       5         train=train_data[features_list],
#       6         valid=valid_data[features_list],
#       7         penalty="l2",
#       8         tol=0.01,
#       9         c=1,
#      10         return_model=return_model,
#      11     )
#      12     if return_model:
#      13         return model
#
# Cell In[14], line 25, in apply_logistic_regression(predict_draws, train, valid, penalty, solver, max_iter, tol, c, return_model)
#      13 X_valid, y_valid = get_x_and_y(valid, predict_draws=predict_draws)
#      15 model = LogisticRegression(
#      16     C=c,  # smaller value -> stronger regularization
#      17     random_state=BASELINE_RANDOM_STATE,
#    (...)
#      22     solver=solver,
#      23 )
# ---> 25 model.fit(X_train, y_train)
#      27 feature_importance = model.coef_
#      28 estimate_baseline_model(
#      29     model, feature_importance, X_train, y_train, X_valid, y_valid
#      30 )
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/mlflow/utils/autologging_utils/safety.py:580, in safe_patch.<locals>.safe_patch_function(*args, **kwargs)
#     578     patch_function.call(call_original, *args, **kwargs)
#     579 else:
# --> 580     patch_function(call_original, *args, **kwargs)
#     582 session.state = "succeeded"
#     584 try_log_autologging_event(
#     585     AutologgingEventLogger.get_logger().log_patch_function_success,
#     586     session,
#    (...)
#     590     kwargs,
#     591 )
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/mlflow/utils/autologging_utils/safety.py:249, in with_managed_run.<locals>.patch_with_managed_run(original, *args, **kwargs)
#     246     managed_run = create_managed_run()
#     248 try:
# --> 249     result = patch_function(original, *args, **kwargs)
#     250 except (Exception, KeyboardInterrupt):
#     251     # In addition to standard Python exceptions, handle keyboard interrupts to ensure
#     252     # that runs are terminated if a user prematurely interrupts training execution
#     253     # (e.g. via sigint / ctrl-c)
#     254     if managed_run:
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/mlflow/sklearn/__init__.py:1653, in _autolog.<locals>.patched_fit(fit_impl, allow_children_patch, original, self, *args, **kwargs)
#    1649 if t.should_log():
#    1650     # In `fit_mlflow` call, it will also call metric API for computing training metrics
#    1651     # so we need temporarily disable the post_training_metrics patching.
#    1652     with _AUTOLOGGING_METRICS_MANAGER.disable_log_post_training_metrics():
# -> 1653         result = fit_impl(original, self, *args, **kwargs)
#    1654     if should_log_post_training_metrics:
#    1655         _AUTOLOGGING_METRICS_MANAGER.register_model(
#    1656             self, mlflow.active_run().info.run_id
#    1657         )
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/mlflow/sklearn/__init__.py:1428, in _autolog.<locals>.fit_mlflow(original, self, *args, **kwargs)
#    1426 _log_pretraining_metadata(autologging_client, self, X, y_true)
#    1427 params_logging_future = autologging_client.flush(synchronous=False)
# -> 1428 fit_output = original(self, *args, **kwargs)
#    1429 _log_posttraining_metadata(autologging_client, self, X, y_true, sample_weight)
#    1430 autologging_client.flush(synchronous=True)
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/mlflow/utils/autologging_utils/safety.py:561, in safe_patch.<locals>.safe_patch_function.<locals>.call_original(*og_args, **og_kwargs)
#     558         original_result = original(*_og_args, **_og_kwargs)
#     559         return original_result
# --> 561 return call_original_fn_with_event_logging(_original_fn, og_args, og_kwargs)
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/mlflow/utils/autologging_utils/safety.py:496, in safe_patch.<locals>.safe_patch_function.<locals>.call_original_fn_with_event_logging(original_fn, og_args, og_kwargs)
#     487 try:
#     488     try_log_autologging_event(
#     489         AutologgingEventLogger.get_logger().log_original_function_start,
#     490         session,
#    (...)
#     494         og_kwargs,
#     495     )
# --> 496     original_fn_result = original_fn(*og_args, **og_kwargs)
#     498     try_log_autologging_event(
#     499         AutologgingEventLogger.get_logger().log_original_function_success,
#     500         session,
#    (...)
#     504         og_kwargs,
#     505     )
#     506     return original_fn_result
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/mlflow/utils/autologging_utils/safety.py:558, in safe_patch.<locals>.safe_patch_function.<locals>.call_original.<locals>._original_fn(*_og_args, **_og_kwargs)
#     550 # Show all non-MLflow warnings as normal (i.e. not as event logs)
#     551 # during original function execution, even if silent mode is enabled
#     552 # (`silent=True`), since these warnings originate from the ML framework
#     553 # or one of its dependencies and are likely relevant to the caller
#     554 with set_non_mlflow_warnings_behavior_for_current_thread(
#     555     disable_warnings=False,
#     556     reroute_warnings=False,
#     557 ):
# --> 558     original_result = original(*_og_args, **_og_kwargs)
#     559     return original_result
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/sklearn/base.py:1472, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1465     estimator._validate_params()
#    1467 with config_context(
#    1468     skip_parameter_validation=(
#    1469         prefer_skip_nested_validation or global_skip_validation
#    1470     )
#    1471 ):
# -> 1472     return fit_method(estimator, *args, **kwargs)
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1350, in LogisticRegression.fit(self, X, y, sample_weight)
#    1347 else:
#    1348     n_threads = 1
# -> 1350 fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#    1351     path_func(
#    1352         X,
#    1353         y,
#    1354         pos_class=class_,
#    1355         Cs=[C_],
#    1356         l1_ratio=self.l1_ratio,
#    1357         fit_intercept=self.fit_intercept,
#    1358         tol=self.tol,
#    1359         verbose=self.verbose,
#    1360         solver=solver,
#    1361         multi_class=multi_class,
#    1362         max_iter=self.max_iter,
#    1363         class_weight=self.class_weight,
#    1364         check_input=False,
#    1365         random_state=self.random_state,
#    1366         coef=warm_start_coef_,
#    1367         penalty=penalty,
#    1368         max_squared_sum=max_squared_sum,
#    1369         sample_weight=sample_weight,
#    1370         n_threads=n_threads,
#    1371     )
#    1372     for class_, warm_start_coef_ in zip(classes_, warm_start_coef)
#    1373 )
#    1375 fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#    1376 self.n_iter_ = np.asarray(n_iter_, dtype=np.int32)[:, 0]
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:547, in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio, n_threads)
#     544         alpha = (1.0 / C) * (1 - l1_ratio)
#     545         beta = (1.0 / C) * l1_ratio
# --> 547     w0, n_iter_i, warm_start_sag = sag_solver(
#     548         X,
#     549         target,
#     550         sample_weight,
#     551         loss,
#     552         alpha,
#     553         beta,
#     554         max_iter,
#     555         tol,
#     556         verbose,
#     557         random_state,
#     558         False,
#     559         max_squared_sum,
#     560         warm_start_sag,
#     561         is_saga=(solver == "saga"),
#     562     )
#     564 else:
#     565     raise ValueError(
#     566         "solver must be one of {'liblinear', 'lbfgs', "
#     567         "'newton-cg', 'sag'}, got '%s' instead" % solver
#     568     )
#
# File ~/PycharmProjects/ChessWinnerPrediction/.venv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:324, in sag_solver(X, y, sample_weight, loss, alpha, beta, max_iter, tol, verbose, random_state, check_input, max_squared_sum, warm_start_mem, is_saga)
#     318     raise ZeroDivisionError(
#     319         "Current sag implementation does not handle "
#     320         "the case step_size * alpha_scaled == 1"
#     321     )
#     323 sag = sag64 if X.dtype == np.float64 else sag32
# --> 324 num_seen, n_iter_ = sag(
#     325     dataset,
#     326     coef_init,
#     327     intercept_init,
#     328     n_samples,
#     329     n_features,
#     330     n_classes,
#     331     tol,
#     332     max_iter,
#     333     loss,
#     334     step_size,
#     335     alpha_scaled,
#     336     beta_scaled,
#     337     sum_gradient_init,
#     338     gradient_memory_init,
#     339     seen_init,
#     340     num_seen_init,
#     341     fit_intercept,
#     342     intercept_sum_gradient,
#     343     intercept_decay,
#     344     is_saga,
#     345     verbose,
#     346 )
#     348 if n_iter_ == max_iter:
#     349     warnings.warn(
#     350         "The max_iter was reached which means the coef_ did not converge",
#     351         ConvergenceWarning,
#     352     )
#
# KeyboardInterrupt:

# %% [markdown]
# ### "MeanElo" and "EloDiff"

# %%
implement_partial_feature_training(features_list=["MeanElo", "EloDiff", "Result"])

# %% [markdown]
# ### "EloDiff", "MeanElo", "ZeroIncrementTime"

# %%
implement_partial_feature_training(
    features_list=["EloDiff", "MeanElo", "ZeroIncrementTime", "Result"]
)

# %% [markdown]
# ### All Features Except "BlackElo", "WhiteElo", "IncrementTime", "BaseTime"

# %%
features = train_data.columns.drop(
    ["BlackElo", "WhiteElo", "IncrementTime", "BaseTime", "Rated Bullet tournament"]
)
log_reg_model = implement_partial_feature_training(
    features_list=features, return_model=True
)

# %% [markdown]
# ## Zero Coefficients

# %%
log_reg_model.feature_names_in_

# %%
log_reg_model.coef_[0:2, 1:] = 0

# %%
log_reg_model.intercept_[2] = -0.17

# %%
X_train, y_train = get_x_and_y(train_data[features], predict_draws=True)
X_valid, y_valid = get_x_and_y(valid_data[features], predict_draws=True)

estimate_baseline_model(
    log_reg_model, log_reg_model.coef_, X_train, y_train, X_valid, y_valid
)
